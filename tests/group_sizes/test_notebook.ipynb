# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

group_sizes_path = r"C:\repos\microbializer\pipeline\tests\groups_sizes.csv"
group_sizes_df = pd.read_csv(group_sizes_path)
sns.histplot(x=group_sizes_df['OG size (number of genomes)'], discrete=True)
plt.xticks(np.unique(group_sizes_df['OG size (number of genomes)']))
# Out:
# ([<matplotlib.axis.XTick at 0x1c502f83790>], [Text(2, 0, '2')])
